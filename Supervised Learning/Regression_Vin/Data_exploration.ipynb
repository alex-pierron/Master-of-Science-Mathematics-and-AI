# %%
from utils import *

# %%
value_counts = data_train["target"].value_counts(sort=True,ascending=True).sort_index(ascending=True)
plt.bar(value_counts.index, value_counts.values)
# Out:
# <BarContainer object of 7 artists>

# %%
import matplotlib.pyplot as plt


num_rows, num_cols = 4, 4  
fig_width, fig_height = 12, 12

fig, axes = plt.subplots(num_rows, num_cols, figsize=(fig_width, fig_height))

axes = axes.ravel()

for i, column in enumerate(data_train.columns):
    ax = axes[i]
    ax.boxplot(data_train[column])
    ax.set_title(column)
    ax.set_xlabel("Value")
    ax.set_ylabel(column)

for i in range(len(data_train.columns), num_rows * num_cols):
    fig.delaxes(axes[i])

plt.tight_layout()

plt.show()

# %%
data_train.head()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine_ID
# 2137               7.2              0.16         0.26             7.1
# 2652               7.3              0.22         0.31             2.3
# 1544               8.9              0.13         0.49             1.0
# 3447               6.0              0.17         0.29             9.7
# 1067               7.5              0.19         0.34             2.6
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# wine_ID
# 2137         0.054                 41.0                 224.0  0.99660  3.38
# 2652         0.018                 45.0                  80.0  0.98936  3.06
# 1544         0.028                  6.0                  24.0  0.99260  2.91
# 3447         0.044                 33.0                  98.0  0.99536  3.12
# 1067         0.037                 33.0                 125.0  0.99230  3.10
#
#          sulphates  alcohol  wine_type  target
# wine_ID
# ...

# %%
data_train.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.220110     0.339852
# volatile acidity           0.220110          1.000000    -0.382732
# citric acid                0.339852         -0.382732     1.000000
# residual sugar            -0.117744         -0.194917     0.139459
# chlorides                  0.295787          0.382517     0.035530
# free sulfur dioxide       -0.290279         -0.350298     0.121678
# total sulfur dioxide      -0.342139         -0.410946     0.179720
# density                    0.463434          0.279881     0.101419
# pH                        -0.263447          0.262562    -0.339331
# sulphates                  0.290388          0.226201     0.061617
# alcohol                   -0.097598         -0.049392    -0.005216
# wine_type                  0.490881          0.650617    -0.179046
# target                    -0.067130         -0.265878     0.089547
#
# ...

# %%
corr_matrix = pd.DataFrame.corr(data_train)
sns.heatmap(corr_matrix, annot=False, fmt='g')
plt.show()

# %%
sns.pairplot(data_train)

# %%
plt.figure(figsize =(15,10))
sns.boxplot(data_train)
# Out:
# <Axes: >

# %% [markdown]
# ### Data engineering
